# %%
import numpy as np
import pandas as pd

# %%
stores = pd.read_csv('stores.csv')
stores.head()
# Out:
#    Store Type    Size
# 0      1    A  151315
# 1      2    A  202307
# 2      3    B   37392
# 3      4    A  205863
# 4      5    B   34875

# %%
stores.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
# Store    45 non-null int64
# Type     45 non-null object
# Size     45 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ KB

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday
# 0      1     1  2010-02-05      24924.50      False
# 1      1     1  2010-02-12      46039.49       True
# 2      1     1  2010-02-19      41595.55      False
# 3      1     1  2010-02-26      19403.54      False
# 4      1     1  2010-03-05      21827.90      False

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    Store  Dept        Date  IsHoliday
# 0      1     1  2012-11-02      False
# 1      1     1  2012-11-09      False
# 2      1     1  2012-11-16      False
# 3      1     1  2012-11-23       True
# 4      1     1  2012-11-30      False

# %%
s_1d_1 = train[(train.Store == 1) & (train.Dept == 1)].drop(['Store', 'Dept'], axis=1)
# %matplotlib inline
s_1d_1.index = s_1d_1.Date
s_1d_1.plot(subplots=True, figsize = (10, 5))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5891f909d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5891a906d0>], dtype=object)

# %%
test['Id'] = ['{}_{}_{}'.format(x, y, z) for x, y, z in test[['Store', 'Dept', 'Date']].values]
len(test['Id'].unique())
# Out:
# 115064

# %%
test.head()
# Out:
#     Store  Dept        Date  IsHoliday              Id
# 0       1     1  2012-11-02      False  1_1_2012-11-02
# 1       1     1  2012-11-09      False  1_1_2012-11-09
# 2       1     1  2012-11-16      False  1_1_2012-11-16
# 3       1     1  2012-11-23       True  1_1_2012-11-23
# 4       1     1  2012-11-30      False  1_1_2012-11-30
# 5       1     1  2012-12-07      False  1_1_2012-12-07
# 6       1     1  2012-12-14      False  1_1_2012-12-14
# 7       1     1  2012-12-21      False  1_1_2012-12-21
# 8       1     1  2012-12-28       True  1_1_2012-12-28
# 9       1     1  2013-01-04      False  1_1_2013-01-04
# 10      1     1  2013-01-11      False  1_1_2013-01-11
# 11      1     1  2013-01-18      False  1_1_2013-01-18
# 12      1     1  2013-01-25      False  1_1_2013-01-25
# 13      1     1  2013-02-01      False  1_1_2013-02-01
# 14      1     1  2013-02-08       True  1_1_2013-02-08
# 15      1     1  2013-02-15      False  1_1_2013-02-15
# ...

# %%
test1 = test[(test.Store == 12) & (test.Dept == 72)]
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39 entries, 31399 to 31437
# Data columns (total 5 columns):
# Store        39 non-null int64
# Dept         39 non-null int64
# Date         39 non-null object
# IsHoliday    39 non-null bool
# Id           39 non-null object
# dtypes: bool(1), int64(2), object(2)
# memory usage: 1.6+ KB

# %%
samples = pd.read_csv('sampleSubmission.csv', index_col=0)
samples.head()
# Out:
#                 Weekly_Sales
# Id
# 1_1_2012-11-02             0
# 1_1_2012-11-09             0
# 1_1_2012-11-16             0
# 1_1_2012-11-23             0
# 1_1_2012-11-30             0

# %%
samples.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115064 entries, 1_1_2012-11-02 to 45_98_2013-07-26
# Data columns (total 1 columns):
# Weekly_Sales    115064 non-null int64
# dtypes: int64(1)
# memory usage: 1.8+ MB

# %%
mission = pd.read_csv('Submission.csv')
mission.head(100)
# Out:
#                 Id  Weekly_Sales
# 0   1_1_2012-11-02  23147.912957
# 1   1_1_2012-11-09  21554.989996
# 2   1_1_2012-11-16  24119.859339
# 3   1_1_2012-11-23  22369.556307
# 4   1_1_2012-11-30  24446.536629
# 5   1_1_2012-12-07  21057.148732
# 6   1_1_2012-12-14  25610.576109
# 7   1_1_2012-12-21  23743.741423
# 8   1_1_2012-12-28  26216.591686
# 9   1_1_2013-01-04  27637.966225
# 10  1_1_2013-01-11  25084.235438
# 11  1_1_2013-01-18  27286.469761
# 12  1_1_2013-01-25  24247.456682
# 13  1_1_2013-02-01  23314.559017
# 14  1_1_2013-02-08  22064.544754
# 15  1_1_2013-02-15  24941.332595
# 16  1_1_2013-02-22  24677.973439
# 17  1_1_2013-03-01  25255.874659
# 18  1_1_2013-03-08  24645.524863
# 19  1_1_2013-03-15  23488.974233
# 20  1_1_2013-03-22  21210.324386
# 21  1_1_2013-03-29  24919.168171
# 22  1_1_2013-04-05  21163.929124
# 23  1_1_2013-04-12  20116.842746
# 24  1_1_2013-04-19  18969.390016
# 25  1_1_2013-04-26  21328.966113
# 26  1_1_2013-05-03  19209.221180
# ...

# %%
mission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 2 columns):
# Id              115064 non-null object
# Weekly_Sales    115064 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.8+ MB

# %%
len(mission.Id.unique())
# Out:
# 32813

# %%
features = pd.read_csv('features.csv')
features.head()
# Out:
#    Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0      1  2010-02-05        42.31       2.572        NaN        NaN
# 1      1  2010-02-12        38.51       2.548        NaN        NaN
# 2      1  2010-02-19        39.93       2.514        NaN        NaN
# 3      1  2010-02-26        46.63       2.561        NaN        NaN
# 4      1  2010-03-05        46.50       2.625        NaN        NaN
#
#    MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment IsHoliday
# 0        NaN        NaN        NaN  211.096358         8.106     False
# 1        NaN        NaN        NaN  211.242170         8.106      True
# 2        NaN        NaN        NaN  211.289143         8.106     False
# 3        NaN        NaN        NaN  211.319643         8.106     False
# 4        NaN        NaN        NaN  211.350143         8.106     False

# %% [markdown]
# # stores

# %%
stores.describe()
# Out:
#            Store           Size
# count  45.000000      45.000000
# mean   23.000000  130287.600000
# std    13.133926   63825.271991
# min     1.000000   34875.000000
# 25%    12.000000   70713.000000
# 50%    23.000000  126512.000000
# 75%    34.000000  202307.000000
# max    45.000000  219622.000000

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
# Store    45 non-null int64
# Type     45 non-null object
# Size     45 non-null int64
# dtypes: int64(2), object(1)
# memory usage: 1.1+ KB

# %%
stores.Type.unique()
# Out:
# array(['A', 'B', 'C'], dtype=object)

# %% [markdown]
# 可以用Store做index

# %%
stores = pd.read_csv('stores.csv', index_col = 'Store')
stores.head()
# Out:
#       Type    Size
# Store
# 1        A  151315
# 2        A  202307
# 3        B   37392
# 4        A  205863
# 5        B   34875

# %%
def v(x):
    d = {'A': 1, 'B': 2, 'C': 3}
    if x in d.keys():
        return d[x]
    else:
        return x
sData = stores.applymap(v)

# %%
sData.head()
# Out:
#        Type    Size
# Store
# 1         1  151315
# 2         1  202307
# 3         2   37392
# 4         1  205863
# 5         2   34875

# %%
# 相关性
sData.corr()
# Out:
#          Type     Size
# Type  1.00000 -0.78589
# Size -0.78589  1.00000

# %% [markdown]
# # train

# %%
len(train.Date.unique())
# Out:
# 143

# %%
train.describe()
# Out:
#                Store           Dept   Weekly_Sales
# count  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123
# std        12.785297      30.492054   22711.183519
# min         1.000000       1.000000   -4988.940000
# 25%        11.000000      18.000000    2079.650000
# 50%        22.000000      37.000000    7612.030000
# 75%        33.000000      74.000000   20205.852500
# max        45.000000      99.000000  693099.360000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Date            421570 non-null object
# Weekly_Sales    421570 non-null float64
# IsHoliday       421570 non-null bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB

# %% [markdown]
# ##### 将时间序列读入

# %%
train = pd.read_csv('train.csv', parse_dates=['Date'])
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
# Store           421570 non-null int64
# Dept            421570 non-null int64
# Date            421570 non-null datetime64[ns]
# Weekly_Sales    421570 non-null float64
# IsHoliday       421570 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(2)
# memory usage: 13.3 MB

# %% [markdown]
# # test

# %%
test = pd.read_csv('test.csv', parse_dates=['Date'])
def b2i(x):
    d = {False: 0, True: 1}
    if x in d.keys():
        return d[x]
    else:
        return x
test.IsHoliday = test.IsHoliday.map(b2i)
test.tail()
# Out:
#         Store  Dept       Date  IsHoliday
# 115059     45    98 2013-06-28          0
# 115060     45    98 2013-07-05          0
# 115061     45    98 2013-07-12          0
# 115062     45    98 2013-07-19          0
# 115063     45    98 2013-07-26          0

# %%
# t45 = test[test.Store == 45]
# t45.Dept.unique()
len(np.sort(test.Date.unique()))
# Out:
# 39

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115064 entries, 0 to 115063
# Data columns (total 4 columns):
# Store        115064 non-null int64
# Dept         115064 non-null int64
# Date         115064 non-null datetime64[ns]
# IsHoliday    115064 non-null int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 3.5 MB

# %%
test.describe()
# Out:
#                Store           Dept      IsHoliday
# count  115064.000000  115064.000000  115064.000000
# mean       22.238207      44.339524       0.077592
# std        12.809930      30.656410       0.267529
# min         1.000000       1.000000       0.000000
# 25%        11.000000      18.000000       0.000000
# 50%        22.000000      37.000000       0.000000
# 75%        33.000000      74.000000       0.000000
# max        45.000000      99.000000       1.000000

# %% [markdown]
# # features

# %%
features = pd.read_csv('features.csv', parse_dates=['Date'])
features.head()
# Out:
#    Store       Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  MarkDown3  \
# 0      1 2010-02-05        42.31       2.572        NaN        NaN        NaN
# 1      1 2010-02-12        38.51       2.548        NaN        NaN        NaN
# 2      1 2010-02-19        39.93       2.514        NaN        NaN        NaN
# 3      1 2010-02-26        46.63       2.561        NaN        NaN        NaN
# 4      1 2010-03-05        46.50       2.625        NaN        NaN        NaN
#
#    MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0        NaN        NaN  211.096358         8.106      False
# 1        NaN        NaN  211.242170         8.106       True
# 2        NaN        NaN  211.289143         8.106      False
# 3        NaN        NaN  211.319643         8.106      False
# 4        NaN        NaN  211.350143         8.106      False

# %%
len(features.Date.unique())
# Out:
# 182

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
# Store           8190 non-null int64
# Date            8190 non-null datetime64[ns]
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# MarkDown1       4032 non-null float64
# MarkDown2       2921 non-null float64
# MarkDown3       3613 non-null float64
# MarkDown4       3464 non-null float64
# MarkDown5       4050 non-null float64
# CPI             7605 non-null float64
# Unemployment    7605 non-null float64
# IsHoliday       8190 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(1)
# memory usage: 711.9 KB

# %%
features.drop(['MarkDown1', 'MarkDown2', 'MarkDown3', 'MarkDown4', 'MarkDown5'], axis=1, inplace=True)

# %%
features.head()
# Out:
#    Store       Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 0      1 2010-02-05        42.31       2.572  211.096358         8.106
# 1      1 2010-02-12        38.51       2.548  211.242170         8.106
# 2      1 2010-02-19        39.93       2.514  211.289143         8.106
# 3      1 2010-02-26        46.63       2.561  211.319643         8.106
# 4      1 2010-03-05        46.50       2.625  211.350143         8.106
#
#    IsHoliday
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False

# %%
features.tail()
# Out:
#       Store       Date  Temperature  Fuel_Price  CPI  Unemployment IsHoliday
# 8185     45 2013-06-28        76.05       3.639  NaN           NaN     False
# 8186     45 2013-07-05        77.50       3.614  NaN           NaN     False
# 8187     45 2013-07-12        79.37       3.614  NaN           NaN     False
# 8188     45 2013-07-19        82.84       3.737  NaN           NaN     False
# 8189     45 2013-07-26        76.06       3.804  NaN           NaN     False

# %%
fs1 = features[features.Store == 1]
fs1.tail()
# Out:
#      Store       Date  Temperature  Fuel_Price  CPI  Unemployment IsHoliday
# 177      1 2013-06-28        83.94       3.495  NaN           NaN     False
# 178      1 2013-07-05        79.85       3.422  NaN           NaN     False
# 179      1 2013-07-12        83.12       3.400  NaN           NaN     False
# 180      1 2013-07-19        79.26       3.556  NaN           NaN     False
# 181      1 2013-07-26        81.54       3.620  NaN           NaN     False

# %%
fs1_ = fs1.dropna()
fs1_.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 169 entries, 0 to 168
# Data columns (total 7 columns):
# Store           169 non-null int64
# Date            169 non-null datetime64[ns]
# Temperature     169 non-null float64
# Fuel_Price      169 non-null float64
# CPI             169 non-null float64
# Unemployment    169 non-null float64
# IsHoliday       169 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(1)
# memory usage: 9.4 KB

# %%
fs1_.describe()
# Out:
#        Store  Temperature  Fuel_Price         CPI  Unemployment
# count  169.0   169.000000  169.000000  169.000000    169.000000
# mean     1.0    66.138047    3.243479  217.271679      7.440994
# std      0.0    14.280976    0.403633    5.004205      0.533324
# min      1.0    35.400000    2.514000  210.337426      6.314000
# 25%      1.0    54.260000    2.835000  211.746754      6.908000
# 50%      1.0    66.760000    3.297000  216.041053      7.742000
# 75%      1.0    79.350000    3.594000  221.883779      7.838000
# max      1.0    91.650000    3.907000  225.170160      8.106000

# %%
fs1 = fs1.fillna(method='ffill')
fs1.tail()
# Out:
#      Store       Date  Temperature  Fuel_Price         CPI  Unemployment  \
# 177      1 2013-06-28        83.94       3.495  217.271679         6.314
# 178      1 2013-07-05        79.85       3.422  217.271679         6.314
# 179      1 2013-07-12        83.12       3.400  217.271679         6.314
# 180      1 2013-07-19        79.26       3.556  217.271679         6.314
# 181      1 2013-07-26        81.54       3.620  217.271679         6.314
#
#     IsHoliday
# 177     False
# 178     False
# 179     False
# 180     False
# 181     False

# %%
fs1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 0 to 181
# Data columns (total 7 columns):
# Store           182 non-null int64
# Date            182 non-null datetime64[ns]
# Temperature     182 non-null float64
# Fuel_Price      182 non-null float64
# CPI             182 non-null float64
# Unemployment    182 non-null float64
# IsHoliday       182 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(1)
# memory usage: 10.1 KB

# %%
fs1.describe()
# Out:
#        Store  Temperature  Fuel_Price         CPI  Unemployment
# count  182.0   182.000000  182.000000  182.000000    182.000000
# mean     1.0    66.912033    3.259242  217.271679      7.360495
# std      0.0    14.134829    0.393400    4.821148      0.590519
# min      1.0    35.400000    2.514000  210.337426      6.314000
# 25%      1.0    55.322500    2.873250  211.835749      6.908000
# 50%      1.0    67.510000    3.354000  217.271679      7.682000
# 75%      1.0    79.857500    3.574000  221.759353      7.838000
# max      1.0    91.650000    3.907000  225.170160      8.106000

# %%
features.fillna(method='ffill', inplace=True)

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 7 columns):
# Store           8190 non-null int64
# Date            8190 non-null datetime64[ns]
# Temperature     8190 non-null float64
# Fuel_Price      8190 non-null float64
# CPI             8190 non-null float64
# Unemployment    8190 non-null float64
# IsHoliday       8190 non-null bool
# dtypes: bool(1), datetime64[ns](1), float64(4), int64(1)
# memory usage: 392.0 KB

# %%
f = features[features.Store == 1].drop(['Store'], axis=1)
f.index = f.Date
f.plot(subplots=True, figsize = (16, 8))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f58911543d0>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f5890f3ced0>], dtype=object)
